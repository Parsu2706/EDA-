# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
customers  = pd.read_csv('Customers.csv' , encoding="latin1")
exchange_rate = pd.read_csv('Exchange_Rates.csv' , encoding="latin1")
products = pd.read_csv('Products.csv' , encoding="latin1")
sales = pd.read_csv('Sales.csv' , encoding="latin1")
store = pd.read_csv('Stores.csv' , encoding="latin1")

# %%
null_value_dataset = []

def overview(dataset):
    
    print(f"{'='*10} Dataset Overview {'='*10}")
    head = dataset.head(5)
    print(head)


    print(f"\n\n {"="*10} Size and Shape of Dataset{"="*10}\n\n")
    print(f"Total Columns : {len(dataset.columns)} \n Total rows :{len(dataset)}")

    print(f"\n\n {"="*10}Data Types of Columns {"="*10}\n\n")
    print(dataset.info())

    print(f"\n\n {"="*10}Null Value Check{"="*10}\n\n")
    dataset.isnull().sum()
    
    print(f"\n\n {"="*10}Duplicate Check{"="*10}\n\n")

    if dataset.duplicated().sum() > 0 : 
        dataset.drop_duplicates(inplace = True)
        print("Removed Duplicate Values")
    else : 
        print("Dataset has zero duplicate values")

    print(f"\n\n {"="*10}Statistical Summary{"="*10}\n\n")
    print(dataset.describe(include = 'all'))


    print("\nCompleted initial data exploration.")

overview(customers)
# Out:
# ========== Dataset Overview ==========
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia    7/3/1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965
#
#
#  ========== Size and Shape of Dataset==========
#
#
# Total Columns : 10
#  Total rows :15266
#
#
# ...

# %%
# cleaning and tranforming data if required

dataset_names = ['customers' , "exchange_rate","store" , "sales" , "products"]
datasets = [customers , exchange_rate,store , sales , products]


for name , df in zip(dataset_names , datasets):
    null_colums  = df.columns[df.isnull().any()]
    if not null_colums.empty :
        print(f'\n column {name} has null values:')
        for col in null_colums:
            pct = ((df[col].isnull().sum() / len(df)) * 100).round(0)
            print(  )
